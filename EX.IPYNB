# %%
class student:
    school='hit'
    def __init__(self):
        self.name='gopal'
        self.age=45
    #@classmethod
    def info(cls):
        return cls.school


s1=student()
s1.info()
# Out:
# 'hit'

# %%
class student:
    school='hit'
    def __init__(self):
        self.name='gopal'
        self.age=45
    # @classmethod
    def info(cls):
        return cls.school


s1=student()
s1.info()
# Out:
# 'hit'

# %%
class Student:
    school = "IIT"

s1 = Student()


s1.school = "NIT"

print(s1.school)

print(Student.school)
# Out:
# NIT
# IIT

# %%
class Student:
    school = "IIT"

s1 = Student()
s2 = Student()

Student.school = "NIT"

print(s1.school)
print(s2.school)
print(Student.school)
# Out:
# NIT
# NIT
# NIT

# %%
class Student:

    def show(self):
        x = 10
        self.y = 20

s1 = Student()
s1.show()

# %%
class Student:

    school = "IIT"

    # @classmethod
    def show(cls):
        print(cls.school)
        

s1=Student()
s1.show()
# Out:
# IIT

# %%
class Student:

    def __init__(sel, name):
        self.name = name
        self.lap = self.Laptop()

    class Laptop:

        def __init__(self):
            self.brand = "Asus"
            self.ram = 8
