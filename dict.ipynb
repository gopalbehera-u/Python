# %% [markdown]
# # creating dictionary

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'name':'gopal','gender':'male|'}

# %%
d1
# Out:
# {'name': 'gopal', 'gender': 'male|'}

# %%
d2={(1,2,3):1,'hello':'world'}
print(d2)# mixed dict
# Out:
# {(1, 2, 3): 1, 'hello': 'world'}

# %%
s={
    'name':'gopal',
    'college':'kit',
    'sem':4,
    'subjects':{
        'dsa':50,
        'maths':56,
        'english':34
    }
}# 2d dictionary

# %%
s
# Out:
# {'name': 'gopal',
#  'college': 'kit',
#  'sem': 4,
#  'subjects': {'dsa': 50, 'maths': 56, 'english': 34}}

# %%
d4=dict([(1,1),(2,3),(4,3)])# using dict func

# %%
d4
# Out:
# {1: 1, 2: 3, 4: 3}

# %%
g={'nme':'gop',[1,23]:5}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 g={'nme':'gop',[1,23]:5}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # accecing items

# %%
d1={'name':'gopal','gender':'male'}
d1['gender']
# Out:
# 'male'

# %% [markdown]
# # Adding key-value

# %%
d1['1']=80

# %%
d1
# Out:
# {'name': 'gopal', 'gender': 'male', '1': 80}

# %% [markdown]
# # remove key-val|ue

# %%
d1.pop('name')
# Out:
# 'gopal'
