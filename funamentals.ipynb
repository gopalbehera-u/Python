# %% [markdown]
# # print output

# %%
print("hello world")
# python is csse sensitive language
# Out:
# hello world

# %%
print(6.5)
print(True)
print(4)
# Out:
# 6.5
# True
# 4

# %%
print("gopal")
# Out:
# gopal

# %%
print("hello",1,4.5,True)
# Out:
# hello 1 4.5 True

# %%
print('hello',1,4.5,True,sep='/')
# Out:
# hello/1/4.5/True

# %%
print('hello',end='-')
print('World')
# Out:
# hello-World

# %% [markdown]
# # Data Types

# %%
# integer 
print(8)
# Out:
# 8

# %%
# decimal
print(6.5)
# Out:
# 6.5

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#test string
print("hello")
# Out:
# hello

# %%
# complex
print(5-6j)
# Out:
# (5-6j)

# %%
# list 
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tuple 
print((12,3,45,53,3))
# Out:
# (12, 3, 45, 53, 3)

# %%
#set
print({12,3,5,6,78,})
# Out:
# {3, 5, 6, 12, 78}

# %%
#dict
print({'name':'nitish',"age":34})
# Out:
# {'name': 'nitish', 'age': 34}

# %%
# type 
type(3)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type('hello')
# Out:
# str

# %%
type(8+7j)
# Out:
# complex

# %%
type(4.3)
# Out:
# float

# %%
type([1,2,3])
# Out:
# list

# %% [markdown]
# # Variable

# %%
name='gopal'
print(name)
# Out:
# gopal

# %%
a=90
print(a)
# Out:
# 90

# %%
b=90
print(a-b)
# Out:
# 0

# %%
# dianmic banding
a=8
print(a)
a="gopal"
print(a)
# Out:
# 8
# gopal

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Keywords & Identifiers

# %%
# keywords
# compiler it convert high level language to machine level langauage 
# interpretor excute line by line 
# compiler execute at a time 
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# you can't start with digit 
# _ underscore is only special character is allowed
# you can't assign var name a keyword
#

# %% [markdown]
# # User input

# %%
input("enter ur name ")
# Out:
# 'gopal'

# %%
fnum=int(input("enter first number "))
snum=int(input("enter seconf number "))
print(fnum,snum)

result=fnum+snum
print(result)
# Out:
# 34 45
# 79

# %% [markdown]
# # type conversion

# %%
# str to int
type(int('4'))
type(int(4.5))

# int to str
str(4)
# Out:
# '4'

# %% [markdown]
# # Litrarals

# %%
a=0b1010 # binary litrarals
b=100 # decimal litrals 
c=0o310 # octal litral
d=0x12c # hexadecimal litral

# float litral
float_1=10.3
float_2=1.5e2

# %%
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# 100

# %%
print(c)
# Out:
# 200

# %%
print(d)
# Out:
# 300

# %%
x=34j
print(x)
# Out:
# 34j

# %%
print(x.real,x.imag)
# Out:
# 0.0 34.0

# %%
string="gopal"
string="""gopwepifwenfw
dkwjebfjwenfjwene

"""
raw=r"/fdkneinfiei"
string='gopal'

# %%
a=True+10
b=False+90

# %%
print(a,b)
# Out:
# 11 90

# %%
k=None
print(k)
# Out:
# None
