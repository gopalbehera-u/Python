# %%
curr_pop=10000
for i in range(10,0,-1):
    print(i,curr_pop)
    curr_pop=curr_pop-0.1*curr_pop
# Out:
# 10 10000
# 9 9000.0
# 8 8100.0
# 7 7290.0
# 6 6561.0
# 5 5904.9
# 4 5314.41
# 3 4782.969
# 2 4304.6721
# 1 3874.20489

# %% [markdown]
# Write a program that will give you in hand monthly salary after deduction on CTC - HRA(10%), DA(5%), PF(3%) and taxes deduction as below:

# %%
salary=int(input("Enter your salary : "))
if salary<500000:
    newsalary=salary*0.10+ salary*0.03+salary*0.05
    salary-=newsalary
    print("your handon salary is : ",salary)
    print("your monthly salary is : ",salary//12)

elif salary<=500000 and salary>1000000:
    newsalary=salary*0.10+ salary*0.03+salary*0.05+salary*0.10
    salary-=newsalary
    print("your handon salary is : ",salary)
    print("your monthly salary is : ",salary//12)

elif salary<=1000000 and salary>2000000:
    newsalary=salary*0.10+ salary*0.03+salary*0.05+salary*0.20
    salary-=newsalary
    print("your handon salary is : ",salary)
    print("your monthly salary is : ",salary//12)

else :
    newsalary=salary*0.10+ salary*0.03+salary*0.05+salary*0.30
    salary-=newsalary
    print("your handon salary is : ",salary)
    print("your monthly salary is : ",salary//12)
# Out:
# your handon salary is :  2.46
# your monthly salary is :  0.0

# %% [markdown]
# Write a program that take a user input of three angles and will find out whether it can form a triangle or not.

# %%
angle1=int(input("Enter your 1st angle : "))
angle2=int(input("Enter your 2nd angle : "))
angle3=int(input("Enter your 3rd angle : "))
total=angle1+angle2+angle3
if total==180:
    print("its an triangle ")
else:
    print("its not an triangle ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 angle1=int(input("Enter your 1st angle : "))
# ----> 2 angle2=int(input("Enter your 2nd angle : "))
#       3 angle3=int(input("Enter your 3rd angle : "))
#       4 total=angle1+angle2+angle3
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# Write a program that will take user input of cost price and selling price and determines whether its a loss or a profit.

# %%
costprice=int(input("Enter Your costprice : "))
sellprice=int(input("Enter Your selling price :  "))
if costprice<sellprice:
    print("profit",sellprice-costprice)
elif costprice>sellprice:
    print("Loss",sellprice-costprice)
else:
    print("no profit no loss ")
# Out:
# profit 22

# %% [markdown]
# Write a menu-driven program -

# %%
parameter=input("Enter Your pararamter u can give these parameter only cm,km,USD : ")
num=int(input("Enter a values positive only  "))
if parameter.lower() == 'cm':
    print(num,"cm is " ,num*0.03,"ft")
elif parameter.lower() == "km":
    print(num,"km is " ,num*0.62,"miles")
elif parameter.lower() == "usd":
    print(num,"usd is " ,num*95,"inr")
else:
    print("EXIT")
# Out:
# EXIT

# %% [markdown]
# Display Fibonacci series up to 10 terms.

# %%
n = int(input("Enter a number: "))

a = 0
b = 1

for i in range(n):
    print(a)
    c = a + b
    a = b
    b = c
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %% [markdown]
# Find the factorial of a given number.

# %%
num=int(input("Enter a number : "))
fact=1
for i in range(1,num+1):
    fact*=i
print(fact)
# Out:
# 120

# %% [markdown]
# Reverse a given integer number.

# %%
num=int(input("Enter your num : "))
rev=0
while num!=0:
    lastdigit=num%10
    rev=rev*10+lastdigit
    num=num//10
    
print(rev)
# Out:
# 321

# %% [markdown]
# Take a user input as integer N. Find out the sum from 1 to N. If any number if divisible by 5, then skip that number. And if the sum is greater than 300, don't need to calculate the sum further more. Print the final result. And don't use for loop to solve this problem.

# %%
num=int(input("Enter a number : "))
sum=0
for i in range(num):
    if i%5==0:
        continue
    elif sum >=300:
        break
    else:
        sum=+i
print(sum)
# Out:
# 299

# %% [markdown]
# Write a program that keeps on accepting a number from the user until the user enters Zero. Display the sum and average of all the numbers.

# %%
num=int(input("Enter your num : "))
sum=0
avg=0
cont=0
while num !=0:
    sum+=num
    cont=cont+1
    avg=sum/cont
    num=int(input("Enter your num : "))
print(sum)
print(avg)
print(cont)
# Out:
# 10
# 3.3333333333333335
# 3
